# %%
! pip install pandas openpyxl seaborn matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: openpyxl in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (3.1.5)
# Requirement already satisfied: seaborn in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: et-xmlfile in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\onedrive\desktop\mp2\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('anemia_dataset.csv')
df_cluster = pd.read_csv('clusters.csv')
df_severity = pd.read_csv('severity.csv')

# %%
df_cluster
# Out:
#       cluster
# 0           1
# 1           2
# 2           2
# 3           2
# 4           2
# ...       ...
# 1129        2
# 1130        0
# 1131        2
# 1132        2
# 1133        0
#
# [1134 rows x 1 columns]

# %%
import os
print(os.listdir())
# Out:
# ['.git', 'anemia_dataset.csv', 'clusters.csv', 'main.py', 'mappings.ipynb', 'microcytic_severity.ipynb', 'microcytic_severity_Clustering.ipynb', 'pooja_data.csv', 'requirements.txt', 'severity.csv', 'venv']

# %%
print(len(df), len(df_cluster), len(df_severity))
df['cluster'] = df_cluster['cluster']
df['severity'] = df_severity['severity']
# Out:
# 1281 1134 1281

# %%
df['cluster']
# Out:
# 0       1.0
# 1       2.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 1276    NaN
# 1277    NaN
# 1278    NaN
# 1279    NaN
# 1280    NaN
# Name: cluster, Length: 1281, dtype: float64

# %%
print(df['severity'])
# Out:
# 0       6.630612
# 1       7.096279
# 2       6.422190
# 3       7.356717
# 4       7.025426
#           ...
# 1276    1.398828
# 1277    0.119619
# 1278    1.267130
# 1279    1.503024
# 1280    0.058093
# Name: severity, Length: 1281, dtype: float64

# %%
df.sample(12)
# Out:
#         WBC    LYMp   NEUTp     LYMn    NEUTn   RBC   HGB      HCT   MCV  \
# 255    5.10  32.000  60.500  1.60000  3.10000  5.38  14.6  45.8000  85.2
# 169    5.20  42.500  51.900  2.20000  2.70000  4.61  10.0  34.9000  75.9
# 285    5.40  36.500  55.000  2.00000  2.90000  4.42  10.9  37.6000  85.1
# 818    6.00  25.845  77.511  1.88076  5.14094  4.00  11.0  46.1526  80.0
# 1170   8.09  25.845  77.511  1.88076  5.14094  4.77  11.5  46.1526  81.8
# 1013   5.84  25.845  77.511  1.88076  5.14094  4.10  11.8  46.1526  94.9
# 798    5.80  25.845  77.511  1.88076  5.14094  3.80  10.6  46.1526  80.0
# 156    8.80  27.100  64.700  2.40000  5.70000  4.87  13.0  42.8000  87.9
# 410    7.60  25.500  65.200  1.90000  5.00000  4.02  10.5  33.5000  83.5
# 297   10.60  19.800  73.000  2.10000  7.70000  5.23  10.8  34.7000  66.5
# 734    7.60  25.845  77.511  1.88076  5.14094  4.70  12.4  46.1526  88.0
# 259    8.80  11.000  81.200  1.00000  7.10000  4.80  13.4  41.5000  86.5
#
#        MCH  MCHC    PLT        PDW      PCT  cluster  severity
# 255   27.1  31.8  182.0  11.800000  0.16000      1.0  1.256720
# 169   21.6  28.6  177.0  12.500000  0.16000      1.0  5.919216
# 285   24.6  28.9  184.0  13.100000  0.18000      1.0  4.319266
# 818   26.0  32.0  200.0  16.000000  0.26028      2.0  4.123596
# 1170  24.1  29.5  238.0  14.312512  0.26028      NaN  4.011017
# 1013  28.8  30.3  166.0  14.312512  0.26028      2.0  2.674693
# 798   26.0  32.0  190.0  14.700000  0.26028      2.0  4.490555
# 156   26.6  30.3  202.0  13.300000  0.19000      2.0  2.088776
# 410   26.1  31.5  208.0  10.500000  0.17000      2.0  4.227489
# 297   20.6  31.1  127.0  16.900000  0.11000      2.0  5.646933
# 734   29.0  33.0  310.0  12.900000  0.26028      0.0  1.501799
# 259   27.9  32.2  162.0  12.800000  0.14000      2.0  1.425309

# %%
cluster_summary = df.groupby('cluster')['severity'].mean()
print(cluster_summary)
# Out:
# cluster
# 0.0    2.282470
# 1.0    3.298578
# 2.0    2.984737
# Name: severity, dtype: float64

# %%
cluster_order = cluster_summary.sort_values().index
print(cluster_order)
# Out:
# Index([0.0, 2.0, 1.0], dtype='float64', name='cluster')

# %%
mapping = {
    cluster_order[0]: 'Normal',
    cluster_order[1]: 'Mild',
    cluster_order[2]: 'Severe'
}

df['category'] = df['cluster'].map(mapping)

# %%
cluster_summary = df.groupby('cluster')['severity'].mean()
print(cluster_summary)
# Out:
# cluster
# 0.0    2.282470
# 1.0    3.298578
# 2.0    2.984737
# Name: severity, dtype: float64

# %%
ranges = df.groupby('category')['severity'].quantile([0.1, 0.9]).unstack()
ranges.columns = ['low','high']
print(ranges)
# Out:
#                low      high
# category
# Mild      0.348471  5.999914
# Normal    0.102770  5.083241
# Severe    0.560384  6.667041
